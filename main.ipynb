# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexPyslar03/aviahack-geoscan/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io
coins = io.imread('flowers.tif')

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.feature import canny

# %%
hist = np.histogram(coins, bins=np.arange(0, 256))
fig, (ax1) = plt.subplots()
ax1.imshow(coins, cmap=plt.cm.gray,interpolation='nearest')

# %%
from skimage.feature import canny
edges = canny(coins/255.)
fig, ax = plt.subplots(figsize=(20, 15))
ax.imshow(edges, cmap=plt.cm.gray, interpolation='nearest')
ax.axis('off')
ax.set_title('Canny detector')
# Out:
# Text(0.5, 1.0, 'Canny detector')

# %%
from scipy import ndimage as ndi
fill_coins = ndi.binary_fill_holes(edges)
fig, ax = plt.subplots(figsize=(20, 15))
ax.imshow(fill_coins, cmap=plt.cm.gray, interpolation='nearest')
ax.axis('off')
ax.set_title('Filling the holes')
# Out:
# Text(0.5, 1.0, 'Filling the holes')

# %%
from skimage.filters import sobel
elevation_map = sobel(coins)
fig, ax = plt.subplots(figsize=(20, 15))
ax.imshow(elevation_map, cmap=plt.cm.gray, interpolation='nearest')
ax.axis('off')
ax.set_title('elevation_map')
# Out:
# Text(0.5, 1.0, 'elevation_map')
